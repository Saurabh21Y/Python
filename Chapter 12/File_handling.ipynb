# %%
story = open(r'D:\movie\story.txt' , 'r')
content=story.read()
print(content)
story.close()

# %%
story = open('story.txt', 'w+')
story.write("Hello World \n")
story.write("This is over write process")

story.seek(0)
text=story.read()
print(text)
story.close()
# Out:
# Hello World
# This is over write process

# %%
rst=open("Man.md",'w')
rst.write("This is generated by code \n")
rst.write("Next tri it with loop")
rst.close()

# %%
for i in range(1,6):
    with open(f"Man{i}.py",'w')as rst:
        rst.write(f"This is file no {i}")
