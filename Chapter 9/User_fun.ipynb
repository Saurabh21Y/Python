# %% [markdown]
# # function
# def <name_function>():
#     code
#
# name_function()
#
# o/p code

# %%
def greet():
    print("Hello!")

greet()

# %%
def greeting(name):
    print(f"Hello {name}")

greeting("Lady")

# %%
def sum(a,b):
    add=a+b
    return add

final=sum(4,8)
print(final)

# %%
def intro(name,age):
    print(f"I am {name} and I am {age} years old")

intro(age=24,name="saurabh")

# %%
def hello(name="user"):
    print(f"Welcome To the game,{name}")

hello()
hello("Saurabh")

# %%
def palindrome(str1):
    rev_str=""
    #rev_str=str1[::-1]
    
    #for i in range(len(str1)-1,-1,-1):
    for i in str1:
        rev_str= i+rev_str

    return rev_str

str1=input("Enter your String: ")
rev_result=palindrome(str1)
if str1==rev_result:
    print("palindrome")
else:
    print("non palindrome")
# Out:
# non palindrome
